# %% [markdown]
# #### 16.04.25, &copy; Barbir Vladyslav KI-21-1

# %% [markdown]
# # Частина друга: Аналіз файлів

# %% [markdown]
# 1. Прочитайте файл `2017_jun_final.csv` за допомогою методу `read_csv`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка під час читання файлу: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.

# %% [markdown]
# 2. Прочитайте отриману таблицю, використовуючи метод `head`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")

    print("\nПерші 5 рядків таблиці:")
    print(df.head())

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка під час читання файлу: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Перші 5 рядків таблиці:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# ...

# %% [markdown]
# 3. Визначте розмір таблиці за допомогою методу `shape`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")

    print("\nПерші 5 рядків таблиці:")
    print(df.head())

    rows, cols = df.shape
    print(f"\nРозмір таблиці:")
    print(f"- Кількість рядків: {rows}")
    print(f"- Кількість стовпців: {cols}")

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка під час читання файлу: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Перші 5 рядків таблиці:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# ...

# %% [markdown]
# 4. Визначте типи всіх стовпців за допомогою `dataframe.dtypes`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")

    rows, cols = df.shape
    print(f"\nРозмір таблиці: {rows} рядків, {cols} стовпців.")

    print("\nТипи даних стовпців:")
    print(df.dtypes)

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка під час читання файлу: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Розмір таблиці: 8704 рядків, 25 стовпців.
#
# Типи даних стовпців:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# ...

# %% [markdown]
# 5. Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи `isnull` і `sum`).

# %%
import pandas as pd

file_path = "2017_jun_final.csv"

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")

    print("\nЧастка пропущених значень (NaN) у кожній колонці:")

    if not df.empty:
        nan_counts = df.isnull().sum()

        total_rows = len(df)

        nan_proportion = nan_counts / total_rows

        print(nan_proportion)
    else:
        print("DataFrame порожній, неможливо розрахувати частку пропусків.")

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка під час читання файлу: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Частка пропущених значень (NaN) у кожній колонці:
# N                                   0.000000
# Должность                           0.000000
# Язык.программирования               0.442325
# Специализация                       0.829389
# Общий.опыт.работы                   0.000000
# Опыт.работы.на.текущем.месте        0.000000
# Зарплата.в.месяц                    0.000000
# Изменение.зарплаты.за.12.месяцев    0.000000
# Город                               0.000000
# Размер.компании                     0.000000
# Тип.компании                        0.000000
# Пол                                 0.000000
# Возраст                             0.000000
# Образование                         0.000000
# Университет                         0.041131
# Еще.студент                         0.000000
# Уровень.английского                 0.000000
# Предметная.область                  0.025620
# Дата.заполнения                     0.000000
# ...

# %% [markdown]
# 6. Видаліть всі стовпці з пропусками, окрім стовпця `"Язык.программирования"`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"
column_to_keep = "Язык.программирования" 

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")
    print(f"Початкова кількість стовпців: {df.shape[1]}")
    print(f"Початкові стовпці: {df.columns.tolist()}")

    columns_with_nan = df.columns[df.isnull().any()].tolist()
    print(f"\nСтовпці, що містять пропуски: {columns_with_nan}")

    columns_to_drop = []
    if column_to_keep not in df.columns:
        print(f"\nПопередження: Стовпець '{column_to_keep}', який потрібно зберегти, відсутній у DataFrame.")
        columns_to_drop = columns_with_nan 
    else:
        for col in columns_with_nan:
            if col != column_to_keep:
                columns_to_drop.append(col)

    print(f"\nСтовпці, що будуть видалені (мають пропуски і не є '{column_to_keep}'): {columns_to_drop}")

    df_cleaned = df.drop(columns=columns_to_drop)

    print("\nСтовпці успішно видалено.")
    print(f"Кінцева кількість стовпців: {df_cleaned.shape[1]}")
    print(f"Кінцеві стовпці: {df_cleaned.columns.tolist()}")


except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
# Початкова кількість стовпців: 25
# Початкові стовпці: ['N', 'Должность', 'Язык.программирования', 'Специализация', 'Общий.опыт.работы', 'Опыт.работы.на.текущем.месте', 'Зарплата.в.месяц', 'Изменение.зарплаты.за.12.месяцев', 'Город', 'Размер.компании', 'Тип.компании', 'Пол', 'Возраст', 'Образование', 'Университет', 'Еще.студент', 'Уровень.английского', 'Предметная.область', 'Дата.заполнения', 'User.Agent', 'exp', 'current_job_exp', 'salary', 'Валюта', 'cls']
#
# Стовпці, що містять пропуски: ['Язык.программирования', 'Специализация', 'Университет', 'Предметная.область', 'Валюта', 'cls']
#
# Стовпці, що будуть видалені (мають пропуски і не є 'Язык.программирования'): ['Специализация', 'Университет', 'Предметная.область', 'Валюта', 'cls']
#
# Стовпці успішно видалено.
# Кінцева кількість стовпців: 20
# ...

# %% [markdown]
# 7. Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився лише стовпець `"Язык.программирования"`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"
column_to_keep = "Язык.программирования" 

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")
    print(f"Початкова кількість стовпців: {df.shape[1]}")

    columns_with_nan_before = df.columns[df.isnull().any()].tolist()
    print(f"\nСтовпці з пропусками ДО видалення: {columns_with_nan_before}")

    columns_to_drop = []
    if column_to_keep not in df.columns:
        print(f"\nПопередження: Стовпець '{column_to_keep}', який потрібно зберегти, відсутній.")
        columns_to_drop = columns_with_nan_before
    else:
        for col in columns_with_nan_before:
            if col != column_to_keep:
                columns_to_drop.append(col)

    print(f"\nСтовпці, що будуть видалені: {columns_to_drop}")

    df_cleaned = df.drop(columns=columns_to_drop)

    print("\nСтовпці успішно видалено.")
    print(f"Кінцева кількість стовпців: {df_cleaned.shape[1]}")
    print(f"Кінцеві стовпці: {df_cleaned.columns.tolist()}")

    print("\nЧастка пропусків у залишених стовпцях:")

    if not df_cleaned.empty:
        nan_counts_after = df_cleaned.isnull().sum()
        total_rows_after = len(df_cleaned)
        nan_proportion_after = nan_counts_after / total_rows_after
        print(nan_proportion_after)

        print("\nПеревірка:")
        columns_with_nan_after = df_cleaned.columns[df_cleaned.isnull().any()].tolist()

        if not columns_with_nan_after:
            print("У жодному із залишених стовпців немає пропусків.")
        elif len(columns_with_nan_after) == 1 and columns_with_nan_after[0] == column_to_keep:
            print(f"Пропуски залишились лише у стовпці '{column_to_keep}', як і очікувалося.")
        else:
            print(f"УВАГА: Пропуски залишились і в інших стовпцях, окрім '{column_to_keep}': {columns_with_nan_after}")

    else:
        print("DataFrame порожній після видалення стовпців.")
    


except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
# Початкова кількість стовпців: 25
#
# Стовпці з пропусками ДО видалення: ['Язык.программирования', 'Специализация', 'Университет', 'Предметная.область', 'Валюта', 'cls']
#
# Стовпці, що будуть видалені: ['Специализация', 'Университет', 'Предметная.область', 'Валюта', 'cls']
#
# Стовпці успішно видалено.
# Кінцева кількість стовпців: 20
# Кінцеві стовпці: ['N', 'Должность', 'Язык.программирования', 'Общий.опыт.работы', 'Опыт.работы.на.текущем.месте', 'Зарплата.в.месяц', 'Изменение.зарплаты.за.12.месяцев', 'Город', 'Размер.компании', 'Тип.компании', 'Пол', 'Возраст', 'Образование', 'Еще.студент', 'Уровень.английского', 'Дата.заполнения', 'User.Agent', 'exp', 'current_job_exp', 'salary']
#
# Частка пропусків у залишених стовпцях:
# N                                   0.000000
# Должность                           0.000000
# Язык.программирования               0.442325
# Общий.опыт.работы                   0.000000
# ...

# %% [markdown]
# 8. Видаліть всі рядки в початковій таблиці за допомогою методу `dropna`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")
    print(f"Початкова розмірність таблиці: {df.shape}")

    print("\nВидалення рядків, що містять хоча б один пропуск...")

    original_row_count = df.shape[0]
    df_dropped_rows = df.dropna() 
    new_row_count = df_dropped_rows.shape[0]

    print("Видалення рядків з пропусками завершено.")
    print(f"Кінцева розмірність таблиці після видалення рядків: {df_dropped_rows.shape}")
    print(f"Було видалено {original_row_count - new_row_count} рядків.")
    
    print("\nПеревірка наявності пропусків після видалення рядків:")
    if not df_dropped_rows.empty:
        remaining_nans = df_dropped_rows.isnull().sum().sum() 
        if remaining_nans == 0:
            print("У таблиці (df_dropped_rows) більше немає пропущених значень.")
        else:
            print(f"УВАГА: Залишилося {remaining_nans} пропущених значень.")
    else:
         print("Таблиця стала порожньою після видалення рядків з пропусками.")

    print("\nПерші 5 рядків таблиці ПІСЛЯ видалення рядків з NaN:")
    print(df_dropped_rows.head())


except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
# Початкова розмірність таблиці: (8704, 25)
#
# Видалення рядків, що містять хоча б один пропуск...
# Видалення рядків з пропусками завершено.
# Кінцева розмірність таблиці після видалення рядків: (0, 25)
# Було видалено 8704 рядків.
#
# Перевірка наявності пропусків після видалення рядків:
# Таблиця стала порожньою після видалення рядків з пропусками.
#
# Перші 5 рядків таблиці ПІСЛЯ видалення рядків з NaN:
# Empty DataFrame
# Columns: [N, Должность, Язык.программирования, Специализация, Общий.опыт.работы, Опыт.работы.на.текущем.месте, Зарплата.в.месяц, Изменение.зарплаты.за.12.месяцев, Город, Размер.компании, Тип.компании, Пол, Возраст, Образование, Университет, Еще.студент, Уровень.английского, Предметная.область, Дата.заполнения, User.Agent, exp, current_job_exp, salary, Валюта, cls]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# 9. Визначте новий розмір таблиці за допомогою методу `shape`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")
    print(f"Початкова розмірність таблиці: {df.shape}")

    print("\nВидалення рядків, що містять хоча б один пропуск...")

    original_row_count = df.shape[0]
    df_dropped_rows = df.dropna()
    new_row_count = df_dropped_rows.shape[0]

    print("Видалення рядків з пропусками завершено.")

    new_rows, new_cols = df_dropped_rows.shape
    print(f"\nНовий розмір таблиці (після видалення рядків з NaN):")
    print(f"- Кількість рядків: {new_rows}")
    print(f"- Кількість стовпців: {new_cols}")
    print(f"(Було видалено {original_row_count - new_row_count} рядків)")

    print("\nПеревірка наявності пропусків після видалення рядків:")
    if not df_dropped_rows.empty:
        remaining_nans = df_dropped_rows.isnull().sum().sum()
        if remaining_nans == 0:
            print("У таблиці (df_dropped_rows) більше немає пропущених значень.")
        else:
            print(f"УВАГА: Залишилося {remaining_nans} пропущених значень.")
    else:
         print("Таблиця стала порожньою після видалення рядків з пропусками.")

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
# Початкова розмірність таблиці: (8704, 25)
#
# Видалення рядків, що містять хоча б один пропуск...
# Видалення рядків з пропусками завершено.
#
# Новий розмір таблиці (після видалення рядків з NaN):
# - Кількість рядків: 0
# - Кількість стовпців: 25
# (Було видалено 8704 рядків)
#
# Перевірка наявності пропусків після видалення рядків:
# Таблиця стала порожньою після видалення рядків з пропусками.

# %% [markdown]
# 10. Створіть нову таблицю `python_data`, в якій будуть лише рядки зі спеціалістами, що вказали мову програмування `Python`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"
language_column = "Язык.программирования" 
target_language = "Python" 

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")
    print(f"Початкова розмірність таблиці: {df.shape}")

    if language_column in df.columns:
        print(f"\nФільтрація даних: вибір рядків, де '{language_column}' == '{target_language}'...")

        python_mask = df[language_column] == target_language
        python_data = df[python_mask]

        print(f"Створено нову таблицю 'python_data'.")
        print(f"Розмірність таблиці 'python_data': {python_data.shape}")

        print(f"\nПерші 5 рядків таблиці 'python_data' (спеціалісти з {target_language}):")
        print(python_data.head())
        
    else:
        print(f"\nПомилка: Стовпець '{language_column}' не знайдено у файлі.")

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
# Початкова розмірність таблиці: (8704, 25)
#
# Фільтрація даних: вибір рядків, де 'Язык.программирования' == 'Python'...
# Створено нову таблицю 'python_data'.
# Розмірність таблиці 'python_data': (207, 25)
#
# Перші 5 рядків таблиці 'python_data' (спеціалісти з Python):
#        N                 Должность Язык.программирования Специализация  \
# 12    13         Software Engineer                Python           NaN
# 68    69         Software Engineer                Python           NaN
# 87    88  Junior Software Engineer                Python           NaN
# 114  115  Junior Software Engineer                Python           NaN
# 143  144  Junior Software Engineer                Python           NaN
#
#     Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 12                  1             меньше 3 месяцев               800
# 68                1.5                          0.5               900
# ...

# %% [markdown]
# 11. Визначте розмір таблиці `python_data` за допомогою методу `shape`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"
language_column = "Язык.программирования"
target_language = "Python"

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")
    if language_column in df.columns:
        print(f"\nФільтрація даних: вибір рядків, де '{language_column}' == '{target_language}'...")

        python_mask = df[language_column] == target_language
        python_data = df[python_mask]

        print(f"Створено нову таблицю 'python_data'.")

        py_rows, py_cols = python_data.shape
        print(f"\nРозмір таблиці 'python_data':")
        print(f"- Кількість рядків: {py_rows}")
        print(f"- Кількість стовпців: {py_cols}")

    else:
        print(f"\nПомилка: Стовпець '{language_column}' не знайдено у файлі.")


except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Фільтрація даних: вибір рядків, де 'Язык.программирования' == 'Python'...
# Створено нову таблицю 'python_data'.
#
# Розмір таблиці 'python_data':
# - Кількість рядків: 207
# - Кількість стовпців: 25

# %% [markdown]
# 12. Використовуючи метод `groupby`, групуйте дані по стовпцю `"Должность"`.

# %%
import pandas as pd

file_path = "2017_jun_final.csv"
language_column = "Язык.программирования" 
target_language = "Python"
position_column = "Должность" 

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")

    if language_column in df.columns and position_column in df.columns:
        
        print(f"\nФільтрація даних: вибір рядків, де '{language_column}' == '{target_language}'...")
        python_mask = df[language_column] == target_language
        python_data = df[python_mask].copy() 

        if not python_data.empty:
             print(f"Створено таблицю 'python_data' розміром: {python_data.shape}")

             print(f"\nГрупування даних таблиці 'python_data' за стовпцем '{position_column}'...")

             grouped_by_position = python_data.groupby(position_column)

             position_counts = grouped_by_position.size()

             print(f"\nКількість Python-спеціалістів за посадою:")
             print(position_counts)

             salary_column = 'Зарплата.в.месяц' 
             if salary_column in python_data.columns:
                  python_data[salary_column] = pd.to_numeric(python_data[salary_column], errors='coerce')
                  avg_salary_by_position = grouped_by_position[salary_column].mean()
                  print(f"\nСередня зарплата Python-спеціалістів за посадою (USD/місяць):")
                  print(avg_salary_by_position.round(2)) 
            
        else:
             print(f"\nТаблиця 'python_data' порожня (не знайдено спеціалістів з {target_language}). Групування неможливе.")

    elif language_column not in df.columns:
         print(f"\nПомилка: Стовпець '{language_column}' не знайдено у файлі.")
    else: 
         print(f"\nПомилка: Стовпець '{position_column}' для групування не знайдено у файлі.")


except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Фільтрація даних: вибір рядків, де 'Язык.программирования' == 'Python'...
# Створено таблицю 'python_data' розміром: (207, 25)
#
# Групування даних таблиці 'python_data' за стовпцем 'Должность'...
#
# Кількість Python-спеціалістів за посадою:
# Должность
# Junior Software Engineer     63
# Senior Software Engineer     31
# Software Engineer           100
# System Architect              2
# Technical Lead               11
# dtype: int64
#
# Середня зарплата Python-спеціалістів за посадою (USD/місяць):
# Должность
# Junior Software Engineer     560.84
# Senior Software Engineer    3387.10
# Software Engineer           1799.07
# System Architect            4000.00
# Technical Lead              3165.91
# Name: Зарплата.в.месяц, dtype: float64

# %% [markdown]
# 13. Створіть новий `DataFrame`, де для сгруппованих даних по стовпцю `"Должность"` виконайте агрегацію даних за допомогою методу `agg` і знайдіть мінімальне і максимальне значення в стовпці `"Зарплата.в.месяц"`.

# %%
import pandas as pd
import numpy as np 

file_path = "2017_jun_final.csv"
language_column = "Язык.программирования" 
target_language = "Python" 
position_column = "Должность"
salary_column = "Зарплата.в.месяц" 

try:
    df = pd.read_csv(file_path)

    print(f"Файл '{file_path}' успішно прочитано.")

    if language_column in df.columns and position_column in df.columns and salary_column in df.columns:
        print(f"\nФільтрація даних: вибір рядків, де '{language_column}' == '{target_language}'...")
        python_mask = df[language_column] == target_language
        python_data = df[python_mask].copy() 

        if not python_data.empty:
             print(f"Створено таблицю 'python_data' розміром: {python_data.shape}")

             print(f"\nПеретворення стовпця '{salary_column}' на числовий тип...")
             python_data[salary_column] = pd.to_numeric(python_data[salary_column], errors='coerce')

             print(f"\nГрупування за '{position_column}' та агрегація min/max для '{salary_column}'...")

             grouped_by_position = python_data.groupby(position_column)

             salary_summary = grouped_by_position[salary_column].agg(['min', 'max'])

             salary_summary = salary_summary.rename(columns={'min': 'Мінімальна зарплата', 'max': 'Максимальна зарплата'})

             print(f"\nСтворено новий DataFrame 'salary_summary' з результатами агрегації:")
             print(salary_summary)
            

        else:
             print(f"\nТаблиця 'python_data' порожня (не знайдено спеціалістів з {target_language}). Агрегація неможлива.")

    elif language_column not in df.columns:
         print(f"\nПомилка: Стовпець '{language_column}' не знайдено у вихідному файлі.")
    elif position_column not in df.columns:
         print(f"\nПомилка: Стовпець '{position_column}' для групування не знайдено у вихідному файлі.")
    else:
         print(f"\nПомилка: Стовпець '{salary_column}' для агрегації не знайдено у вихідному файлі.")


except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Фільтрація даних: вибір рядків, де 'Язык.программирования' == 'Python'...
# Створено таблицю 'python_data' розміром: (207, 25)
#
# Перетворення стовпця 'Зарплата.в.месяц' на числовий тип...
#
# Групування за 'Должность' та агрегація min/max для 'Зарплата.в.месяц'...
#
# Створено новий DataFrame 'salary_summary' з результатами агрегації:
#                           Мінімальна зарплата  Максимальна зарплата
# Должность
# Junior Software Engineer                  100                  1250
# Senior Software Engineer                 1300                  9200
# Software Engineer                         500                  5400
# System Architect                         3000                  5000
# Technical Lead                           1425                  6200

# %% [markdown]
# 14. Створіть функцію `fill_avg_salary`, яка буде повертати середнє значення заробітної плати в місяць. Використовуйте її для методу `apply` і створіть новий стовпець `"avg"`.

# %%
import pandas as pd
import numpy as np

file_path = "2017_jun_final.csv"
language_column = "Язык.программирования"
target_language = "Python"
position_column = "Должность"
salary_column = "Зарплата.в.месяц"

try:
    df = pd.read_csv(file_path)
    print(f"Файл '{file_path}' успішно прочитано.")

    if language_column in df.columns and salary_column in df.columns:
       
        print(f"\nФільтрація даних для {target_language}...")
        python_mask = df[language_column] == target_language
        python_data = df[python_mask].copy()

        if not python_data.empty:
            print(f"Створено таблицю 'python_data' розміром: {python_data.shape}")

            print(f"\nПеретворення стовпця '{salary_column}' на числовий тип...")
            python_data[salary_column] = pd.to_numeric(python_data[salary_column], errors='coerce')

            if python_data[salary_column].notna().any():
                overall_avg_salary = python_data[salary_column].mean()
                print(f"\nЗагальна середня зарплата для {target_language}-спеціалістів: {overall_avg_salary:.2f}")

                def fill_avg_salary(row):
                    return overall_avg_salary

                print(f"\nСтворення нового стовпця 'avg', застосовуючи функцію fill_avg_salary...")
             
                python_data['avg'] = python_data.apply(fill_avg_salary, axis=1)
                print("Стовпець 'avg' створено.")

                print("\nПерші 5 рядків таблиці 'python_data' з новим стовпцем 'avg':")
               
                print(python_data[[position_column, salary_column, 'avg']].head())
            else:
                print(f"\nНеможливо розрахувати середню зарплату: стовпець '{salary_column}' не містить числових значень у відфільтрованих даних.")

        else:
            print(f"\nТаблиця 'python_data' порожня (не знайдено спеціалістів з {target_language}).")

    elif language_column not in df.columns:
        print(f"\nПомилка: Стовпець '{language_column}' не знайдено у вихідному файлі.")
    else: 
        print(f"\nПомилка: Стовпець '{salary_column}' не знайдено у вихідному файлі.")

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Фільтрація даних для Python...
# Створено таблицю 'python_data' розміром: (207, 25)
#
# Перетворення стовпця 'Зарплата.в.месяц' на числовий тип...
#
# Загальна середня зарплата для Python-спеціалістів: 1753.94
#
# Створення нового стовпця 'avg', застосовуючи функцію fill_avg_salary...
# Стовпець 'avg' створено.
#
# Перші 5 рядків таблиці 'python_data' з новим стовпцем 'avg':
#                     Должность  Зарплата.в.месяц          avg
# 12          Software Engineer               800  1753.937198
# 68          Software Engineer               900  1753.937198
# 87   Junior Software Engineer               600  1753.937198
# 114  Junior Software Engineer               685  1753.937198
# 143  Junior Software Engineer               750  1753.937198

# %% [markdown]
# 15. Створіть описову статистику за допомогою методу `describe` для нового стовпця.

# %%
import pandas as pd
import numpy as np

file_path = "2017_jun_final.csv"
language_column = "Язык.программирования"
target_language = "Python"
position_column = "Должность"
salary_column = "Зарплата.в.месяц"

try:
    df = pd.read_csv(file_path)
    print(f"Файл '{file_path}' успішно прочитано.")

    if language_column in df.columns and salary_column in df.columns:
        print(f"\nФільтрація даних для {target_language}...")
        python_mask = df[language_column] == target_language
        python_data = df[python_mask].copy()

        if not python_data.empty:
            print(f"Створено таблицю 'python_data' розміром: {python_data.shape}")

            print(f"\nПеретворення стовпця '{salary_column}' на числовий тип...")
            python_data[salary_column] = pd.to_numeric(python_data[salary_column], errors='coerce')

            if python_data[salary_column].notna().any():
                overall_avg_salary = python_data[salary_column].mean()
                print(f"\nЗагальна середня зарплата для {target_language}-спеціалістів: {overall_avg_salary:.2f}")

                def fill_avg_salary(row):
                    return overall_avg_salary

                print(f"\nСтворення нового стовпця 'avg'...")
                python_data['avg'] = python_data.apply(fill_avg_salary, axis=1)
                print("Стовпець 'avg' створено.")

                print(f"\nОписова статистика для стовпця 'avg':")
                avg_description = python_data['avg'].describe()
                print(avg_description)
               

            else:
                print(f"\nНеможливо розрахувати середню зарплату: стовпець '{salary_column}' не містить числових значень.")

        else:
            print(f"\nТаблиця 'python_data' порожня (не знайдено спеціалістів з {target_language}).")

    elif language_column not in df.columns:
        print(f"\nПомилка: Стовпець '{language_column}' не знайдено у вихідному файлі.")
    else: 
        print(f"\nПомилка: Стовпець '{salary_column}' не знайдено у вихідному файлі.")

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Фільтрація даних для Python...
# Створено таблицю 'python_data' розміром: (207, 25)
#
# Перетворення стовпця 'Зарплата.в.месяц' на числовий тип...
#
# Загальна середня зарплата для Python-спеціалістів: 1753.94
#
# Створення нового стовпця 'avg'...
# Стовпець 'avg' створено.
#
# Описова статистика для стовпця 'avg':
# count    2.070000e+02
# mean     1.753937e+03
# std      5.014347e-12
# min      1.753937e+03
# 25%      1.753937e+03
# 50%      1.753937e+03
# 75%      1.753937e+03
# max      1.753937e+03
# Name: avg, dtype: float64

# %% [markdown]
# 16. Збережіть отриману таблицю в CSV файл.

# %%
import pandas as pd
import numpy as np

input_file_path = "2017_jun_final.csv"
output_file_path = "python_developers_avg_salary.csv" 
language_column = "Язык.программирования"
target_language = "Python"
position_column = "Должность"
salary_column = "Зарплата.в.месяц"

try:
    df = pd.read_csv(input_file_path)
    print(f"Файл '{input_file_path}' успішно прочитано.")

    if language_column in df.columns and salary_column in df.columns:
        print(f"\nФільтрація даних для {target_language}...")
        python_mask = df[language_column] == target_language
        python_data = df[python_mask].copy()

        if not python_data.empty:
            print(f"Створено таблицю 'python_data' розміром: {python_data.shape}")

            print(f"\nПеретворення стовпця '{salary_column}' на числовий тип...")
            python_data[salary_column] = pd.to_numeric(python_data[salary_column], errors='coerce')

            if python_data[salary_column].notna().any():
                overall_avg_salary = python_data[salary_column].mean()
                print(f"\nЗагальна середня зарплата для {target_language}-спеціалістів: {overall_avg_salary:.2f}")

                def fill_avg_salary(row):
                    return overall_avg_salary

                print(f"\nСтворення нового стовпця 'avg'...")
                python_data['avg'] = python_data.apply(fill_avg_salary, axis=1)
                print("Стовпець 'avg' створено.")

                print(f"\nОписова статистика для стовпця 'avg':")
                print(python_data['avg'].describe())

                print(f"\nЗбереження таблиці 'python_data' у файл '{output_file_path}'...")
                python_data.to_csv(output_file_path, index=False, encoding='utf-8-sig')
                print(f"Таблицю успішно збережено у файл '{output_file_path}'.")

            else:
                print(f"\nНеможливо розрахувати середню зарплату та створити стовпець 'avg'. Збереження не виконується.")

        else:
            print(f"\nТаблиця 'python_data' порожня. Збереження не виконується.")

    elif language_column not in df.columns:
        print(f"\nПомилка: Стовпець '{language_column}' не знайдено у вихідному файлі.")
    else: 
        print(f"\nПомилка: Стовпець '{salary_column}' не знайдено у вихідному файлі.")

except FileNotFoundError:
    print(f"Помилка: Файл не знайдено за вказаним шляхом: {input_file_path}")
    print("Будь ласка, перевірте правильність шляху та наявність файлу.")
except pd.errors.EmptyDataError:
    print(f"Помилка: Файл '{input_file_path}' порожній.")
except pd.errors.ParserError:
     print(f"Помилка: Не вдалося обробити файл '{input_file_path}'. Можливо, він має неправильний формат CSV.")
except Exception as e:
    print(f"Сталася невідома помилка: {e}")
# Out:
# Файл '2017_jun_final.csv' успішно прочитано.
#
# Фільтрація даних для Python...
# Створено таблицю 'python_data' розміром: (207, 25)
#
# Перетворення стовпця 'Зарплата.в.месяц' на числовий тип...
#
# Загальна середня зарплата для Python-спеціалістів: 1753.94
#
# Створення нового стовпця 'avg'...
# Стовпець 'avg' створено.
#
# Описова статистика для стовпця 'avg':
# count    2.070000e+02
# mean     1.753937e+03
# std      5.014347e-12
# min      1.753937e+03
# 25%      1.753937e+03
# 50%      1.753937e+03
# 75%      1.753937e+03
# max      1.753937e+03
# Name: avg, dtype: float64
#
# Збереження таблиці 'python_data' у файл 'python_developers_avg_salary.csv'...
# Таблицю успішно збережено у файл 'python_developers_avg_salary.csv'.
